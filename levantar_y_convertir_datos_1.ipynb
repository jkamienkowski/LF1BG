# %%
# IMPORTACIÓN DE LAS BIBLIOTECAS QUE NECESITAMOS USAR
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

# %%
# IMPORTACIÓN DE LOS DATOS DESDE UN ARCHIVO DE EXCEL
directorio = 'datos_hojas/'
nombrearchivo='masalargoanchoarea.csv'
data = pd.read_csv(directorio + nombrearchivo,header=None)
data
# Out:
#                                           0
# 0    1.18,0.01,14.8,0.1,4.0,0.1,35.34,0.001
# 1    1.75,0.01,15.5,0.1,4.5,0.1,52.15,0.001
# 2   2.06,0.01,26.6,0.1,6.5,0.1,106.05,0.001
# 3    2.11,0.01,9.1,0.1,10.1,0.1,63.30,0.001
# 4    3.52,0.01,8.2,0.1,11.1,0.1,67.35,0.001
# 5     0.49,0.01,8.4,0.1,3.5,0.1,20.20,0.001
# 6    0.66,0.01,8.8,0.1,25.2,0.1,28.57,0.001
# 7      0.14,0.01,2.8,0.1,2.9,0.1,6.78,0.001
# 8     0.18,0.01,6.6,0.1,6.1,0.1,23.13,0.001
# 9    0.31,0.01,10.1,0.1,3.1,0.1,20.52,0.001
# 10   1.25,0.01,10.2,0.1,5.8,0.1,35.83,0.001
# 11    0.49,0.01,9.2,0.1,3.5,0.1,25.93,0.001
# 12     0.16,0.01,3.0,0.1,3.2,0.1,6.90,0.001
# 13     0.09,0.01,3.7,0.1,1.8,0.1,4.51,0.001
# 14     0.16,0.01,3.5,0.1,2.1,0.1,4.76,0.001
# 15     0.08,0.01,3.7,0.1,1.5,0.1,3.30,0.001
# 16     0.09,0.01,3.8,0.1,2.1,0.1,4.11,0.001
# 17   0.54,0.01,12.2,0.1,3.3,0.1,25.55,0.001
# 18      0.63,0.01,7.5,0.1,3,0.1,18.12,0.001
# 19   0.71,0.01,11.5,0.1,4.4,0.1,37.14,0.001
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
TMP = [] 
for i in range(0,len(data)):
    tmp = data[0][i].split(",")
    tmp = [ float(x) for x in tmp ]
    TMP.append(tmp)
data2 = pd.DataFrame(TMP)
data2
# Out:
#        0     1     2    3     4    5       6      7
# 0   1.18  0.01  14.8  0.1   4.0  0.1   35.34  0.001
# 1   1.75  0.01  15.5  0.1   4.5  0.1   52.15  0.001
# 2   2.06  0.01  26.6  0.1   6.5  0.1  106.05  0.001
# 3   2.11  0.01   9.1  0.1  10.1  0.1   63.30  0.001
# 4   3.52  0.01   8.2  0.1  11.1  0.1   67.35  0.001
# 5   0.49  0.01   8.4  0.1   3.5  0.1   20.20  0.001
# 6   0.66  0.01   8.8  0.1  25.2  0.1   28.57  0.001
# 7   0.14  0.01   2.8  0.1   2.9  0.1    6.78  0.001
# 8   0.18  0.01   6.6  0.1   6.1  0.1   23.13  0.001
# 9   0.31  0.01  10.1  0.1   3.1  0.1   20.52  0.001
# 10  1.25  0.01  10.2  0.1   5.8  0.1   35.83  0.001
# 11  0.49  0.01   9.2  0.1   3.5  0.1   25.93  0.001
# 12  0.16  0.01   3.0  0.1   3.2  0.1    6.90  0.001
# 13  0.09  0.01   3.7  0.1   1.8  0.1    4.51  0.001
# 14  0.16  0.01   3.5  0.1   2.1  0.1    4.76  0.001
# 15  0.08  0.01   3.7  0.1   1.5  0.1    3.30  0.001
# 16  0.09  0.01   3.8  0.1   2.1  0.1    4.11  0.001
# ...

# %%
# Si bien no es necesario para todos los analisis, en muchos casos no convertir a un vector 
# (sin el formato de tabla) puede traer errores futuros, por ejemplo al calcular diferencias.
variable1 = np.asarray(data2[0])
variable2 = np.asarray(data2[1])
variable3 = np.asarray(data2[2])
variable4 = np.asarray(data2[3])
variable5 = np.asarray(data2[4])
variable6 = np.asarray(data2[5])
variable7 = np.asarray(data2[6])
variable8 = np.asarray(data2[7])
variable1
# Out:
# array([ 1.18,  1.75,  2.06,  2.11,  3.52,  0.49,  0.66,  0.14,  0.18,
#         0.31,  1.25,  0.49,  0.16,  0.09,  0.16,  0.08,  0.09,  0.54,
#         0.63,  0.71,  0.37,  0.5 ,  0.24,  0.1 ,  0.2 ,  0.28,  4.27,
#         0.16,  0.22,  0.09])
